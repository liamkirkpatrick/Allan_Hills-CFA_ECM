# %% [markdown]
# # Hailey's first ECM notebook for IBIS!
#
# This notebook is a starting point for exploring ECM data in python. It assumes you have ECM datafiles stored in the same directory as the notebook.

# %% [markdown]
# ## First up, load packages
#
# You'll need to do this at the start of every notebook.
#
# By now, you should have installed the following packages using conda in your environment:
# - pandas
# - numpy
# - matplotlib

# %%
# these are common imports for data analysis and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Next, load the data

# %%
# here we load data from the ALHIC2201 core
alhic2201_data = pd.read_csv('data/ALHIC2201_ECM_binned.csv')

# the "head" function displays the first few rows of the dataframe. This let's us quickly inspect the data in a spreadsheet-like format.
alhic2201_data.head()
# Out:
#    depth_m            AC        DC
# 0    0.015  1.480000e-08  0.000005
# 1    0.025  1.470000e-08  0.000005
# 2    0.035  1.460000e-08  0.000006
# 3    0.045  1.430000e-08  0.000006
# 4    0.055  1.390000e-08  0.000006

# %%
alhic2302_data = pd.read_csv('data/ALHIC2302_ECM_binned.csv')

alhic2302_data.head()
# Out:
#    depth_m            AC        DC
# 0    8.485  1.150000e-08  0.000003
# 1    8.495  1.120000e-08  0.000003
# 2    8.505  1.080000e-08  0.000003
# 3    8.515  1.060000e-08  0.000004
# 4    8.525  1.040000e-08  0.000004

# %% [markdown]
# ## Now, let's make a simple plot to visualize some aspect of the data.

# %%
# first, some basic code to start a plot
fig, ax = plt.subplots(figsize=(8, 6))

# plot the ECM data from the ALHIC2201 core
ax.plot(alhic2201_data['depth_m'], alhic2201_data['AC'])

# %% [markdown]
# ## Now it's your turn!
#
# Some suggested tasks to take on:
#
# 1. Make sure you can plot both AC and DC data.
# 2. Try plotting AC and DC data in two subplots on the same figure. Use plt.subplots(1,2) to create a figure with one row and two columns. Google to figure out the right syntax.
# 3. Often, we plot ice core data with depth increasing downwards on the y-axis. Try to make a plot that does this. I suggest using plt.ylim(high value, low value) to reverse the y-axis. Pick appropriate high and low values for your depth data.
# 4. Label your axis, using ax.set_xlabel() and x.set_ylabel() commands.
# 5. Add a title to your plot using ax.set_title(). Add a label to each subplot if you are using subplots using ax[0].set_title() and ax[1].set_title() commands.
# 6. Can you look up how to change the color of your plot line? Try changing it to red.
# 7. Can you add grid lines to your plot? Look up how to do this online.
# 8. Can you add a legend to your plot with labels for each line? Look up how to do this online.
# 9. Can you zoom in on a specific depth range of interest? Try using plt.ylim() to set appropriate y-axis limits.
# 10. Can you save your figure as a .png file? Look up how to do this online. You might think about creating a folder called "figures" in your working directory to save your plots in an organized way. You'll have to specify the path to that folder when you save your figure.

# %%
# Let's make a plot with two subplots
fig, ax = plt.subplots(2,1)

ax[0].plot(alhic2201_data['depth_m'], alhic2201_data['AC'])
ax[1].plot(alhic2201_data['depth_m'], alhic2201_data['DC'])

# %%
fix, ax = plt.subplots()

ax.plot(alhic2201_data['depth_m'], alhic2201_data['AC'],'r')
ax.plot(alhic2201_data['depth_m'], alhic2201_data['DC'],'b')
